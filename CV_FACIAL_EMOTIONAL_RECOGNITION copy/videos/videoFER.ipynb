# %%
import os
os.environ["IMAGEIO_FFMPEG_EXE"] = "/path/to/ffmpeg"

from fer import FER
from fer import Video
import pandas as pd
import matplotlib.pyplot as plt
video_file: str = "JPowell.mp4"

face_detector: FER = FER(mtcnn=True)

# preprocess video file
processed_video = Video(video_file=video_file)

processing_data = processed_video.analyze(face_detector,display=True)

df= pd.DataFrame(processing_data)
# Out:
# INFO:fer:29.97 fps, 1169 frames, 39.01 seconds
# INFO:fer:Making directories at output
#   6%|▌         | 72/1169 [00:15<04:33,  4.02frames/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      12 # preprocess video file
#      13 processed_video = Video(video_file=video_file)
# ---> 15 processing_data = processed_video.analyze(face_detector,display=True)
#      17 df= pd.DataFrame(processing_data)
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/fer/classes.py:318, in Video.analyze(self, detector, display, output, frequency, max_results, save_fps, video_id, save_frames, save_video, annotate_frames, zip_images, detection_box, lang, include_audio, size_multiplier)
#     316 # Get faces and detect emotions; coordinates are for unpadded frame
#     317 try:
# --> 318     faces = detector.detect_emotions(frame)
#     319 except Exception as e:
#     320     log.error(e)
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/fer/fer.py:251, in FER.detect_emotions(self, img, face_rectangles)
#     248 emotion_labels = self._get_labels()
#     250 if face_rectangles is None:
# --> 251     face_rectangles = self.find_faces(img, bgr=True)
#     253 gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     254 gray_img = self.pad(gray_img)
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/fer/fer.py:189, in FER.find_faces(self, img, bgr)
#     181     faces = self.__face_detector.detectMultiScale(
#     182         gray_image_array,
#     183         scaleFactor=self.__scale_factor,
#    (...)
#     186         minSize=(self.__min_face_size, self.__min_face_size),
#     187     )
#     188 elif self.__face_detector == "mtcnn":
# --> 189     boxes, probs = self._mtcnn.detect(img)
#     190     faces = []
#     191     if type(boxes) == np.ndarray:
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/facenet_pytorch/models/mtcnn.py:313, in MTCNN.detect(self, img, landmarks)
#     273 """Detect all faces in PIL image and return bounding boxes and optional facial landmarks.
#     274
#     275 This method is used by the forward method and is also useful for face detection tasks
#    (...)
#     309 >>> img_draw.save('annotated_faces.png')
#     310 """
#     312 with torch.no_grad():
# --> 313     batch_boxes, batch_points = detect_face(
#     314         img, self.min_face_size,
#     315         self.pnet, self.rnet, self.onet,
#     316         self.thresholds, self.factor,
#     317         self.device
#     318     )
#     320 boxes, probs, points = [], [], []
#     321 for box, point in zip(batch_boxes, batch_points):
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/facenet_pytorch/models/utils/detect_face.py:112, in detect_face(imgs, minsize, pnet, rnet, onet, threshold, factor, device)
#     110     if ey[k] > (y[k] - 1) and ex[k] > (x[k] - 1):
#     111         img_k = imgs[image_inds[k], :, (y[k] - 1):ey[k], (x[k] - 1):ex[k]].unsqueeze(0)
# --> 112         im_data.append(imresample(img_k, (24, 24)))
#     113 im_data = torch.cat(im_data, dim=0)
#     114 im_data = (im_data - 127.5) * 0.0078125
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/facenet_pytorch/models/utils/detect_face.py:305, in imresample(img, sz)
#     304 def imresample(img, sz):
# --> 305     im_data = interpolate(img, size=sz, mode="area")
#     306     return im_data
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/torch/nn/functional.py:4017, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4015 if input.dim() == 4 and mode == "area":
#    4016     assert output_size is not None
# -> 4017     return adaptive_avg_pool2d(input, output_size)
#    4018 if input.dim() == 5 and mode == "area":
#    4019     assert output_size is not None
#
# File ~/Desktop/FACIAL_EMOTIONAL_RECOGNITION/.conda/lib/python3.9/site-packages/torch/nn/functional.py:1233, in adaptive_avg_pool2d(input, output_size)
#    1231     return handle_torch_function(adaptive_avg_pool2d, (input,), input, output_size)
#    1232 _output_size = _list_with_default(output_size, input.size())
# -> 1233 return torch._C._nn.adaptive_avg_pool2d(input, _output_size)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# use the data  to decide the our execution/approach

df.dropna(axis=1,inplace=True)
df['seconds']=df.index
df
# Out:
#                       box0  angry0  disgust0  fear0  happy0  sad0  surprise0  \
# 0     [538, 120, 170, 214]    0.25       0.0   0.20    0.01  0.11       0.01
# 1     [539, 121, 169, 211]    0.26       0.0   0.31    0.00  0.10       0.02
# 2     [537, 121, 170, 213]    0.28       0.0   0.22    0.01  0.09       0.01
# 3     [536, 119, 173, 220]    0.32       0.0   0.27    0.01  0.12       0.01
# 4     [538, 119, 171, 217]    0.13       0.0   0.34    0.02  0.11       0.01
# ...                    ...     ...       ...    ...     ...   ...        ...
# 1089  [570, 144, 165, 213]    0.06       0.0   0.01    0.04  0.02       0.01
# 1090  [565, 141, 164, 214]    0.05       0.0   0.00    0.07  0.03       0.00
# 1091  [567, 142, 166, 211]    0.06       0.0   0.00    0.08  0.02       0.00
# 1092  [568, 139, 166, 211]    0.07       0.0   0.00    0.05  0.03       0.00
# 1093  [568, 145, 166, 208]    0.17       0.0   0.04    0.01  0.11       0.01
#
#       neutral  seconds  positive  negative
# 0        0.43        0      0.02      0.56
# 1        0.30        1      0.02      0.67
# 2        0.39        2      0.02      0.59
# 3        0.27        3      0.02      0.71
# 4        0.38        4      0.03      0.58
# ...       ...      ...       ...       ...
# 1089     0.87     1089      0.05      0.09
# 1090     0.86     1090      0.07      0.08
# 1091     0.83     1091      0.08      0.08
# 1092     0.85     1092      0.05      0.10
# 1093     0.66     1093      0.02      0.32
#
# [1094 rows x 11 columns]

# %%
df['positive']=df['happy0']+df['surprise0']
df['negative']=df['angry0']+df['disgust0']+df['fear0']+df['sad0']

# Correct the dictionary for renaming
neutral_dict = {'neutral0': 'neutral'}

# Use the rename method with the columns parameter
df.rename(columns=neutral_dict, inplace=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['seconds'], df['negative'], c='red', label='Negative Points')

plt.xlabel('Seconds')
plt.ylabel('Negative Score')
plt.title('Scatter Plot of Negative Points Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df[(df['negative']>=0.4) & (df['negative']>df['neutral'])].reset_index(drop=True)
# Out:
#                      box0  angry0  disgust0  fear0  happy0  sad0  surprise0  \
# 0    [538, 120, 170, 214]    0.25       0.0   0.20    0.01  0.11       0.01
# 1    [539, 121, 169, 211]    0.26       0.0   0.31    0.00  0.10       0.02
# 2    [537, 121, 170, 213]    0.28       0.0   0.22    0.01  0.09       0.01
# 3    [536, 119, 173, 220]    0.32       0.0   0.27    0.01  0.12       0.01
# 4    [538, 119, 171, 217]    0.13       0.0   0.34    0.02  0.11       0.01
# ..                    ...     ...       ...    ...     ...   ...        ...
# 267  [570, 156, 161, 207]    0.32       0.0   0.10    0.02  0.06       0.04
# 268  [553, 128, 171, 221]    0.48       0.0   0.02    0.02  0.08       0.01
# 269  [550, 126, 174, 225]    0.46       0.0   0.03    0.05  0.04       0.01
# 270  [549, 124, 177, 232]    0.49       0.0   0.02    0.13  0.06       0.00
# 271  [555, 139, 172, 223]    0.31       0.0   0.11    0.14  0.17       0.01
#
#      neutral  seconds  positive  negative
# 0       0.43        0      0.02      0.56
# 1       0.30        1      0.02      0.67
# 2       0.39        2      0.02      0.59
# 3       0.27        3      0.02      0.71
# 4       0.38        4      0.03      0.58
# ..       ...      ...       ...       ...
# 267     0.45      999      0.06      0.48
# 268     0.39     1022      0.03      0.58
# 269     0.42     1023      0.06      0.53
# 270     0.29     1026      0.13      0.57
# 271     0.25     1029      0.15      0.59
#
# [272 rows x 11 columns]
